# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
token = gkey

base_url = 'https://api.genius.com'
headers = {'Authorization': 'Bearer ' + token}
search_url = base_url + '/search'

# USER INPUT SONG SEARCH
song_title = input('Enter a song title: ')
artist_name = input('Enter an artist name: ')
params = {'q': song_title + ' ' + artist_name}
response = requests.get(search_url, params=params, headers=headers)

response.json()
# Out:
# Enter a song title:
# Enter an artist name: Flying Lotus
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 18,
#      'api_path': '/songs/511769',
#      'full_title': 'Never Catch Me by\xa0Flying\xa0Lotus (Ft.\xa0Kendrick\xa0Lamar)',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/6c2126fe520242295cbea822cb15c683.300x300x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/6c2126fe520242295cbea822cb15c683.658x658x1.jpg',
#      'id': 511769,
#      'lyrics_owner_id': 104344,
#      'lyrics_state': 'complete',
#      'path': '/Flying-lotus-never-catch-me-lyrics',
#      'pyongs_count': 169,
#      'song_art_image_thumbnail_url': 'https://images.rapgenius.com/b3821a78cbe122f1aabf758513f2f2b4.300x397x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 241209},
#      'title': 'Never Catch Me',
# ...

# %%
script that grab list of songs, run all thru apis calls, scrape and download into a data structure
