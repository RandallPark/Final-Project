# %% [markdown]
# ## Tokenize words to get frequency

# %%
# The Embedding layer takes at least two arguments:
# the number of possible words in the vocabulary, here 1000 (1 + maximum word index),
# and the dimensionality of the embeddings, here 32.
embedding_layer = layers.Embedding(1000, 32)

# %%
import pandas as pd
# from nltk.sentiment.vader import SentimentIntensityAnalyzer
# import nltk
# nltk.download('vader_lexicon')

import os
# path = './data/analyzed_tweets'
path = './resources/analyzed_tweets'

# os function to ('*.csv') - returns files[str]

csv_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            csv_files.append(os.path.join(r, file))

for f in csv_files:
    print(f)
    
# tweet_df = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index = True)
# tweet_df
# Out:
# ./data/analyzed_tweets/polarity_joebiden_ft.csv
# ./data/analyzed_tweets/polarity_senwarren_ft.csv
# ./data/analyzed_tweets/polarity_republican_ft.csv
# ./data/analyzed_tweets/polarity_housegop_ft.csv
# ./data/analyzed_tweets/polarity_berniesanders_ft.csv
# ./data/analyzed_tweets/polarity_mikepence_ft.csv
# ./data/analyzed_tweets/polarity_marcorubio_ft.csv
# ./data/analyzed_tweets/polarity_tedcruz_ft.csv
# ./data/analyzed_tweets/polarity_donaldtrump_ft.csv
# ./data/analyzed_tweets/polarity_senatedemocrats_ft.csv
# ./data/analyzed_tweets/polarity_lizcheney_ft.csv
# ./data/analyzed_tweets/polarity_democrats_ft.csv
# ./data/analyzed_tweets/polarity_housedemocrats_ft.csv
# ./data/analyzed_tweets/polarity_senaterepublican_ft.csv
#        Unnamed: 0 Political Affiliation  \
# 0               0             Democrats
# 1               1             Democrats
# 2               2             Democrats
# 3               3             Democrats
# 4               4             Democrats
# 5               5             Democrats
# 6               6             Democrats
# 7               7             Democrats
# 8               8             Democrats
# 9               9             Democrats
# 10             10             Democrats
# 11             11             Democrats
# 12             12             Democrats
# 13             13             Democrats
# 14             14             Democrats
# 15             15             Democrats
# 16             16             Democrats
# 17             17             Democrats
# 18             18             Democrats
# 19             19             Democrats
# 20             20             Democrats
# 21             21             Democrats
# 22             22             Democrats
# 23             23             Democrats
# 24             24             Democrats
# 25             25             Democrats
# 26             26             Democrats
# 27             27             Democrats
# 28             28             Democrats
# 29             29             Democrats
# ...           ...                   ...
# 46974        1855            Republican
# 46975        1856            Republican
# 46976        1857            Republican
# 46977        1858            Republican
# 46978        1859            Republican
# 46979        1860            Republican
# 46980        1861            Republican
# 46981        1862            Republican
# 46982        1863            Republican
# 46983        1864            Republican
# 46984        1865            Republican
# 46985        1866            Republican
# 46986        1867            Republican
# 46987        1868            Republican
# 46988        1869            Republican
# 46989        1870            Republican
# 46990        1871            Republican
# 46991        1872            Republican
# 46992        1873            Republican
# 46993        1874            Republican
# 46994        1875            Republican
# 46995        1876            Republican
# 46996        1877            Republican
# 46997        1878            Republican
# 46998        1879            Republican
# 46999        1880            Republican
# 47000        1881            Republican
# 47001        1882            Republican
# 47002        1883            Republican
# 47003        1884            Republican
#
#                                                    tweet  \
# 0      We're in a battle for the soul of this nation....
# 1      Today marks 50 years since the Stonewall upris...
# 2      I’ve fought my heart out to ensure that civil ...
# 3      At last night’s first Democratic debate, I lai...
# 4      I just got off the debate stage, where I laid ...
# 5      That’s a wrap! Thanks for following along with...
# 6      "There's not a single thing the American peopl...
# 7      We know NATO will fall apart if Donald Trump i...
# 8      Retweet if you're proud to be on #TeamJoe! #De...
# 9      The Biden administration will make the largest...
# 10     The members of the NRA are not our opponents —...
# 11     The Iraq war was a strategic mistake that cost...
# 12     Joe Biden shepherded through the Brady Backgro...
# 13     Climate change is a global challenge that requ...
# 14     As President, Joe Biden will export our clean-...
# 15     Joe Biden played a key role in securing the ex...
# 16     “We would reunite those families, period.” #De...
# 17     Our immigration system must be fixed without t...
# 18     As Vice President, Joe Biden worked with the l...
# 19     "Health care is personal to me... there are pe...
# 20     Now, we need to finish the job and make health...
# 21     As VP, Joe Biden stood shoulder to shoulder wi...
# 22                               https://t.co/H3a61KTPQM
# 23     We've got to do better for our educators and o...
# 24     This country wasn’t built by Wall Street banke...
# 25     Hey everyone — @TeamJoe here! We’re taking ove...
# 26     I’m about to take the debate stage. The large,...
# 27     We have to choose hope over fear, truth over l...
# 28     We can do all this and more – all that stands ...
# 29     Climate change is an existential threat. We ha...
# ...                                                  ...
# 46974  Economists agree: \n“We believe the Republican...
# 46975  “Anything we can do to help small businesses i...
# 46976  Economists’ letter: “How Tax Reform Will Lift ...
# 46977  "If we’re going to create more small businesse...
# 46978  "If we’re going to create more small businesse...
# 46979  "My dad worked very hard, often seven days a w...
# 46980  “We need #TaxReform, and we need it now.” – @S...
# 46981  The @Pardoned_Turkey takes a trot through Wash...
# 46982  Does the @Pardoned_Turkey call Turkey bacon, j...
# 46983  The @Pardoned_Turkey tours Washington this Tha...
# 46984  What will the @Pardoned_Turkey do next? https:...
# 46985  “Our tax cut plan repeals the Obamacare’s indi...
# 46986  "Every income group under the Senate bill will...
# 46987  "Republicans are right: Slashing Obamacare’s r...
# 46988  "Sen. Tom Cotton says 'every income group' wil...
# 46989  "The Health 202: Republicans are right. The in...
# 46990  "We're going to take what is arguably the wors...
# 46991  "The 'mandate repeal is a tax hike' argument s...
# 46992  "@NFIB Praises Senate Finance Action on #TaxRe...
# 46993  "Repealing the mandate is a tax cut for lower-...
# 46994  @SenToomey @jctgov .@SenToomey: “It doesn’t di...
# 46995  @SenToomey @jctgov .@SenToomey: “There’s no [#...
# 46996  .@SenToomey: "Mr. Barthold, can you tell me wh...
# 46997  What tax reform means for Alabama: 12,640 new ...
# 46998  What tax reform means for Illinois: 38,465 new...
# 46999  The Senate Republican Tax Cuts &amp; Jobs Act ...
# 47000  Michigan is ready for the 27,672 new jobs it w...
# 47001  "A family that makes around $70,000 will have ...
# 47002  California is ready for the 105,410 new jobs t...
# 47003  Senate Republicans are working on tax reform t...
#
#                  Politician  Word Count  negative  neutral  positive  polarity
# 0                 Joe Biden        46.0     0.039    0.961     0.000   -0.2023
# 1                 Joe Biden        45.0     0.050    0.772     0.178    0.7650
# 2                 Joe Biden        50.0     0.043    0.860     0.097    0.4404
# 3                 Joe Biden        43.0     0.000    0.845     0.155    0.6808
# 4                 Joe Biden        51.0     0.000    0.875     0.125    0.6486
# 5                 Joe Biden        32.0     0.000    0.841     0.159    0.6696
# 6                 Joe Biden        13.0     0.000    1.000     0.000    0.0000
# 7                 Joe Biden        30.0     0.000    0.912     0.088    0.4215
# 8                 Joe Biden        10.0     0.000    0.726     0.274    0.5255
# 9                 Joe Biden        32.0     0.000    0.689     0.311    0.8807
# 10                Joe Biden        39.0     0.125    0.812     0.063   -0.4019
# 11                Joe Biden        35.0     0.254    0.678     0.068   -0.7709
# 12                Joe Biden        31.0     0.257    0.743     0.000   -0.8658
# 13                Joe Biden        39.0     0.000    0.918     0.082    0.2960
# 14                Joe Biden        22.0     0.000    0.909     0.091    0.2732
# 15                Joe Biden        34.0     0.000    0.804     0.196    0.7430
# 16                Joe Biden         8.0     0.000    1.000     0.000    0.0000
# 17                Joe Biden        25.0     0.000    0.909     0.091    0.3400
# 18                Joe Biden        36.0     0.105    0.895     0.000   -0.6249
# 19                Joe Biden        30.0     0.000    0.815     0.185    0.7096
# 20                Joe Biden        23.0     0.087    0.782     0.132    0.2709
# 21                Joe Biden        43.0     0.000    0.862     0.138    0.7269
# 22                Joe Biden         1.0     0.000    1.000     0.000    0.0000
# 23                Joe Biden        44.0     0.032    0.813     0.156    0.6705
# 24                Joe Biden        34.0     0.000    1.000     0.000    0.0000
# 25                Joe Biden        33.0     0.000    0.920     0.080    0.4003
# 26                Joe Biden        35.0     0.000    0.849     0.151    0.6908
# 27                Joe Biden        49.0     0.100    0.651     0.248    0.7823
# 28                Joe Biden        52.0     0.060    0.940     0.000   -0.4767
# 29                Joe Biden        42.0     0.208    0.708     0.084   -0.8164
# ...                     ...         ...       ...      ...       ...       ...
# 46974  Senate of Republican        24.0     0.000    0.809     0.191    0.6369
# 46975  Senate of Republican        20.0     0.000    0.810     0.190    0.4588
# 46976  Senate of Republican        12.0     0.000    1.000     0.000    0.0000
# 46977  Senate of Republican        44.0     0.000    0.909     0.091    0.4588
# 46978  Senate of Republican        44.0     0.000    0.909     0.091    0.4588
# 46979  Senate of Republican        38.0     0.102    0.825     0.073   -0.0498
# 46980  Senate of Republican        12.0     0.000    1.000     0.000    0.0000
# 46981  Senate of Republican        10.0     0.000    1.000     0.000    0.0000
# 46982  Senate of Republican        12.0     0.000    1.000     0.000    0.0000
# 46983  Senate of Republican         7.0     0.000    1.000     0.000    0.0000
# 46984  Senate of Republican         7.0     0.000    1.000     0.000    0.0000
# 46985  Senate of Republican        23.0     0.373    0.627     0.000   -0.8658
# 46986  Senate of Republican        17.0     0.000    1.000     0.000    0.0000
# 46987  Senate of Republican        23.0     0.181    0.819     0.000   -0.4939
# 46988  Senate of Republican        18.0     0.116    0.884     0.000   -0.2732
# 46989  Senate of Republican        20.0     0.000    1.000     0.000    0.0000
# 46990  Senate of Republican        27.0     0.203    0.797     0.000   -0.7269
# 46991  Senate of Republican        38.0     0.168    0.785     0.047   -0.5574
# 46992  Senate of Republican        11.0     0.000    0.746     0.254    0.5267
# 46993  Senate of Republican        17.0     0.130    0.870     0.000   -0.2732
# 46994  Senate of Republican        33.0     0.080    0.920     0.000   -0.4215
# 46995  Senate of Republican        23.0     0.091    0.909     0.000   -0.2960
# 46996  Senate of Republican        41.0     0.052    0.948     0.000   -0.2960
# 46997  Senate of Republican        18.0     0.000    0.874     0.126    0.3182
# 46998  Senate of Republican        18.0     0.000    0.874     0.126    0.3182
# 46999  Senate of Republican        28.0     0.075    0.925     0.000   -0.2960
# 47000  Senate of Republican        15.0     0.000    0.848     0.152    0.3612
# 47001  Senate of Republican        17.0     0.000    1.000     0.000    0.0000
# 47002  Senate of Republican        22.0     0.081    0.701     0.218    0.5719
# 47003  Senate of Republican        20.0     0.000    0.773     0.227    0.6486
#
# [47004 rows x 9 columns]

# %%
biden_tweet_df = pd.read_csv(csv_files[0], index_col=0)
biden_tweet_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  We're in a battle for the soul of this nation....
# 1             Democrats  Today marks 50 years since the Stonewall upris...
# 2             Democrats  I’ve fought my heart out to ensure that civil ...
# 3             Democrats  At last night’s first Democratic debate, I lai...
# 4             Democrats  I just got off the debate stage, where I laid ...
#
#   Politician  Word Count  negative  neutral  positive  polarity
# 0  Joe Biden          46     0.039    0.961     0.000   -0.2023
# 1  Joe Biden          45     0.050    0.772     0.178    0.7650
# 2  Joe Biden          50     0.043    0.860     0.097    0.4404
# 3  Joe Biden          43     0.000    0.845     0.155    0.6808
# 4  Joe Biden          51     0.000    0.875     0.125    0.6486

# %%
X_data_biden = biden_tweet_df['tweet'].copy()
X_data_biden.head()
# Out:
# 0    We're in a battle for the soul of this nation....
# 1    Today marks 50 years since the Stonewall upris...
# 2    I’ve fought my heart out to ensure that civil ...
# 3    At last night’s first Democratic debate, I lai...
# 4    I just got off the debate stage, where I laid ...
# Name: tweet, dtype: object

# %%
biden_tweet_df.columns
# Out:
# Index(['Political_Affiliation', 'tweet', 'Politician', 'Word_Count',
#        'negative', 'neutral', 'positive', 'polarity'],
#       dtype='object')

# %%
# 'negative', 'neutral', 'positive'

y_data = biden_tweet_df[['negative', 'neutral', 'positive']].copy()
y_data.head()
# Out:
#    negative  neutral  positive
# 0     0.039    0.961     0.000
# 1     0.050    0.772     0.178
# 2     0.043    0.860     0.097
# 3     0.000    0.845     0.155
# 4     0.000    0.875     0.125

# %%
biden_tweet_df.groupby("Political Affiliation").mean()
# Out:
#                         Unnamed: 0  Word Count  negative   neutral  positive  \
# Political Affiliation
# Democrats              2797.511487   28.970621  0.082681  0.800128  0.117191
# Republican             4179.693695   30.252752  0.076268  0.786793  0.136935
#
#                        polarity
# Political Affiliation
# Democrats              0.100536
# Republican             0.142881

# %% [markdown]
# ## Learning embeddings from scratch

# %% [markdown]
# We will train a sentiment classifier on tweets. In the process, we will learn embeddings from scratch. We will move quickly through the code that downloads and preprocesses the dataset (see this [tutorial](https://www.tensorflow.org/tutorials/keras/basic_text_classification) for more details).

# %%
import time
from tensorflow.python.keras.preprocessing.text import Tokenizer
#this must match with the embedding layer
num_words = 1000

tokenizer_biden = Tokenizer(num_words=num_words)

# %%time

tokenizer_biden.fit_on_texts(X_data_biden)

# %%
tokenizer_biden.word_counts['grassroots']
# Out:
# 9

# %%
tokenizer_biden.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'co': 3,
#  't': 4,
#  'and': 5,
#  'in': 6,
#  'a': 7,
#  'of': 8,
#  'http': 9,
#  'for': 10,
#  'https': 11,
#  'on': 12,
#  'biden': 13,
#  'we': 14,
#  'is': 15,
#  'our': 16,
#  'this': 17,
#  'you': 18,
#  'vp': 19,
#  'president': 20,
#  'that': 21,
#  'with': 22,
#  'i': 23,
#  'are': 24,
#  'it': 25,
#  'be': 26,
#  '”': 27,
#  'at': 28,
#  'who': 29,
#  'have': 30,
#  'today': 31,
#  'will': 32,
#  'up': 33,
#  'not': 34,
#  'your': 35,
#  'all': 36,
#  'about': 37,
#  'out': 38,
#  'from': 39,
#  'country': 40,
#  'their': 41,
#  'as': 42,
#  'us': 43,
#  'make': 44,
#  'my': 45,
#  'people': 46,
#  'by': 47,
#  'they': 48,
#  'day': 49,
#  'more': 50,
#  'america': 51,
#  'every': 52,
#  'it’s': 53,
#  'was': 54,
#  'his': 55,
#  'amp': 56,
#  'obama': 57,
#  'has': 58,
#  'what': 59,
#  'get': 60,
#  'one': 61,
#  'romney': 62,
#  'middle': 63,
#  'an': 64,
#  'vote': 65,
#  'can': 66,
#  'work': 67,
#  'joe': 68,
#  'but': 69,
#  'class': 70,
#  '”—vp': 71,
#  'women': 72,
#  'do': 73,
#  'back': 74,
#  'campaign': 75,
#  'now': 76,
#  '—': 77,
#  'so': 78,
#  'no': 79,
#  'he': 80,
#  'years': 81,
#  'last': 82,
#  'american': 83,
#  'or': 84,
#  'take': 85,
#  'if': 86,
#  'time': 87,
#  'need': 88,
#  'plan': 89,
#  'join': 90,
#  'than': 91,
#  'must': 92,
#  'know': 93,
#  'how': 94,
#  'vice': 95,
#  'me': 96,
#  'them': 97,
#  'never': 98,
#  'great': 99,
#  'new': 100,
#  'just': 101,
#  'there': 102,
#  'jill': 103,
#  'right': 104,
#  'we’re': 105,
#  'should': 106,
#  'trump': 107,
#  'like': 108,
#  'watch': 109,
#  'those': 110,
#  'i’m': 111,
#  'made': 112,
#  'stand': 113,
#  'first': 114,
#  'here': 115,
#  'families': 116,
#  'violence': 117,
#  'see': 118,
#  'nation': 119,
#  'would': 120,
#  'health': 121,
#  'care': 122,
#  'dr': 123,
#  'against': 124,
#  'week': 125,
#  'everyone': 126,
#  'proud': 127,
#  'way': 128,
#  'when': 129,
#  'forward': 130,
#  'americans': 131,
#  'tax': 132,
#  'been': 133,
#  'ryan': 134,
#  'got': 135,
#  'jobs': 136,
#  'help': 137,
#  'election': 138,
#  'rights': 139,
#  'debate': 140,
#  'why': 141,
#  'sure': 142,
#  'act': 143,
#  'thank': 144,
#  'year': 145,
#  'yesterday': 146,
#  'world': 147,
#  'because': 148,
#  'over': 149,
#  'going': 150,
#  'hope': 151,
#  'change': 152,
#  'better': 153,
#  'happy': 154,
#  'go': 155,
#  'these': 156,
#  'support': 157,
#  '“the': 158,
#  'ohio': 159,
#  'through': 160,
#  'progress': 161,
#  'live': 162,
#  'fight': 163,
#  'future': 164,
#  'much': 165,
#  'down': 166,
#  'tomorrow': 167,
#  'say': 168,
#  'off': 169,
#  '“we': 170,
#  'security': 171,
#  'good': 172,
#  'where': 173,
#  'together': 174,
#  'teamjoe': 175,
#  'only': 176,
#  'medicare': 177,
#  'community': 178,
#  'lives': 179,
#  'that’s': 180,
#  'most': 181,
#  'action': 182,
#  'working': 183,
#  "it's": 184,
#  'iowa': 185,
#  'still': 186,
#  'states': 187,
#  'give': 188,
#  'being': 189,
#  'before': 190,
#  'family': 191,
#  'keep': 192,
#  'climate': 193,
#  'across': 194,
#  'pay': 195,
#  'education': 196,
#  'stop': 197,
#  'love': 198,
#  'her': 199,
#  'don’t': 200,
#  'always': 201,
#  '–joe': 202,
#  'end': 203,
#  'dignity': 204,
#  'voting': 205,
#  'tonight': 206,
#  'many': 207,
#  'romney’s': 208,
#  'mitt': 209,
#  'ever': 210,
#  'life': 211,
#  'everything': 212,
#  'administration': 213,
#  'head': 214,
#  'ago': 215,
#  'come': 216,
#  'friend': 217,
#  'next': 218,
#  'folks': 219,
#  'economy': 220,
#  'without': 221,
#  'into': 222,
#  'making': 223,
#  'senate': 224,
#  'children': 225,
#  'we’ve': 226,
#  'national': 227,
#  'too': 228,
#  'photo': 229,
#  'can’t': 230,
#  'we’ll': 231,
#  'assault': 232,
#  'any': 233,
#  'call': 234,
#  'want': 235,
#  'barackobama': 236,
#  'talk': 237,
#  'protect': 238,
#  'single': 239,
#  'united': 240,
#  'million': 241,
#  'students': 242,
#  'believe': 243,
#  'democracy': 244,
#  'courage': 245,
#  'rsvp': 246,
#  'clear': 247,
#  'state': 248,
#  'teachers': 249,
#  'fighting': 250,
#  'policy': 251,
#  "don't": 252,
#  "we're": 253,
#  'again': 254,
#  'i’ve': 255,
#  'ensure': 256,
#  'built': 257,
#  'home': 258,
#  'job': 259,
#  'tune': 260,
#  'incredible': 261,
#  'workers': 262,
#  'party': 263,
#  'hard': 264,
#  'speech': 265,
#  'look': 266,
#  'she': 267,
#  'win': 268,
#  'deserve': 269,
#  'demdebate': 270,
#  'done': 271,
#  'night': 272,
#  'had': 273,
#  'important': 274,
#  'getting': 275,
#  'safe': 276,
#  'values': 277,
#  'own': 278,
#  'congress': 279,
#  'after': 280,
#  'policies': 281,
#  'could': 282,
#  'speak': 283,
#  'remember': 284,
#  'young': 285,
#  'men': 286,
#  "i'm": 287,
#  'ready': 288,
#  'president’s': 289,
#  'soul': 290,
#  'energy': 291,
#  'its': 292,
#  'system': 293,
#  'few': 294,
#  'able': 295,
#  'public': 296,
#  'put': 297,
#  'him': 298,
#  'foreign': 299,
#  'best': 300,
#  'friends': 301,
#  'find': 302,
#  'step': 303,
#  'story': 304,
#  'obama2012': 305,
#  'lgbtq': 306,
#  'vision': 307,
#  'thanks': 308,
#  'follow': 309,
#  'under': 310,
#  'cut': 311,
#  'communities': 312,
#  'days': 313,
#  'college': 314,
#  'event': 315,
#  'nothing': 316,
#  'were': 317,
#  'let': 318,
#  'choice': 319,
#  'some': 320,
#  'barack': 321,
#  'part': 322,
#  'heart': 323,
#  'democratic': 324,
#  "there's": 325,
#  'stage': 326,
#  'there’s': 327,
#  '–': 328,
#  'let’s': 329,
#  'donald': 330,
#  'gun': 331,
#  'high': 332,
#  "we've": 333,
#  'sexual': 334,
#  'read': 335,
#  'cuts': 336,
#  'think': 337,
#  'check': 338,
#  'bring': 339,
#  '000': 340,
#  'ofa': 341,
#  'obama’s': 342,
#  'move': 343,
#  'since': 344,
#  'thing': 345,
#  "can't": 346,
#  'around': 347,
#  'different': 348,
#  'said': 349,
#  'means': 350,
#  'very': 351,
#  'promise': 352,
#  'enough': 353,
#  'firefighters': 354,
#  'place': 355,
#  'honor': 356,
#  'you’re': 357,
#  '1': 358,
#  'share': 359,
#  'culture': 360,
#  'vp’s': 361,
#  'continue': 362,
#  'full': 363,
#  'running': 364,
#  'clean': 365,
#  'power': 366,
#  'lead': 367,
#  'leaders': 368,
#  'economic': 369,
#  'affordable': 370,
#  'issues': 371,
#  'past': 372,
#  'fair': 373,
#  'another': 374,
#  'sign': 375,
#  'weekend': 376,
#  'cancer': 377,
#  'other': 378,
#  'law': 379,
#  'doesn’t': 380,
#  'et': 381,
#  'word': 382,
#  'birthday': 383,
#  'coming': 384,
#  '3': 385,
#  '5': 386,
#  'strong': 387,
#  'itsonus': 388,
#  '—vp': 389,
#  'biden’s': 390,
#  '”—dr': 391,
#  'politics': 392,
#  'doing': 393,
#  "let's": 394,
#  'treated': 395,
#  'history': 396,
#  'military': 397,
#  'bill': 398,
#  'value': 399,
#  'taking': 400,
#  'rally': 401,
#  'court': 402,
#  'house': 403,
#  'far': 404,
#  'speaking': 405,
#  'wage': 406,
#  'big': 407,
#  'break': 408,
#  'gets': 409,
#  'matters': 410,
#  'may': 411,
#  'looking': 412,
#  'philadelphia': 413,
#  'pennsylvania': 414,
#  '10': 415,
#  "that's": 416,
#  'video': 417,
#  'november': 418,
#  'taxes': 419,
#  '“they': 420,
#  'equal': 421,
#  'team': 422,
#  'along': 423,
#  'four': 424,
#  'access': 425,
#  'educators': 426,
#  'provide': 427,
#  'i’ll': 428,
#  'hate': 429,
#  'industry': 430,
#  'real': 431,
#  'iran': 432,
#  'leadership': 433,
#  'standing': 434,
#  'convention': 435,
#  'old': 436,
#  'long': 437,
#  'man': 438,
#  'thousands': 439,
#  'benefits': 440,
#  'tell': 441,
#  'well': 442,
#  'grow': 443,
#  'did': 444,
#  'hampshire': 445,
#  'creating': 446,
#  'left': 447,
#  'service': 448,
#  'character': 449,
#  'line': 450,
#  'fired': 451,
#  'visit': 452,
#  'chance': 453,
#  'during': 454,
#  'show': 455,
#  'budget': 456,
#  'bet': 457,
#  '“i': 458,
#  'u': 459,
#  's': 460,
#  'millions': 461,
#  'giving': 462,
#  'facts': 463,
#  'fear': 464,
#  'you’ll': 465,
#  'between': 466,
#  'code': 467,
#  'rebuild': 468,
#  'am': 469,
#  'white': 470,
#  'wrong': 471,
#  'already': 472,
#  'continues': 473,
#  'whether': 474,
#  'social': 475,
#  'honored': 476,
#  'woman': 477,
#  'trip': 478,
#  'opportunity': 479,
#  '2': 480,
#  'commitment': 481,
#  'virginia': 482,
#  'miss': 483,
#  'person': 484,
#  'near': 485,
#  'john': 486,
#  'florida': 487,
#  'early': 488,
#  'gov': 489,
#  'photos': 490,
#  '“he': 491,
#  'respect': 492,
#  'heard': 493,
#  'elected': 494,
#  'war': 495,
#  'personal': 496,
#  'term': 497,
#  'threat': 498,
#  'teacher': 499,
#  'build': 500,
#  'america’s': 501,
#  'income': 502,
#  'comes': 503,
#  'restore': 504,
#  'today’s': 505,
#  'supreme': 506,
#  'set': 507,
#  'voters': 508,
#  'turn': 509,
#  'supporters': 510,
#  'trump’s': 511,
#  'month': 512,
#  'minimum': 513,
#  'heading': 514,
#  'shot': 515,
#  'china': 516,
#  'knows': 517,
#  '12': 518,
#  'meet': 519,
#  'missed': 520,
#  'latest': 521,
#  'matter': 522,
#  'vawa': 523,
#  'wish': 524,
#  'moving': 525,
#  'century': 526,
#  'send': 527,
#  'ones': 528,
#  'elect': 529,
#  'americanpromisetour': 530,
#  'road': 531,
#  'lot': 532,
#  'favorite': 533,
#  'auto': 534,
#  'division': 535,
#  'fought': 536,
#  'two': 537,
#  'nra': 538,
#  'starts': 539,
#  'which': 540,
#  'things': 541,
#  'tonight’s': 542,
#  'discuss': 543,
#  'hear': 544,
#  'invest': 545,
#  'race': 546,
#  'deserves': 547,
#  'needs': 548,
#  'efforts': 549,
#  'human': 550,
#  'having': 551,
#  'presidential': 552,
#  'living': 553,
#  'kids': 554,
#  'office': 555,
#  'isn’t': 556,
#  'talking': 557,
#  'responders': 558,
#  'student': 559,
#  'bidens': 560,
#  'makes': 561,
#  'peace': 562,
#  'does': 563,
#  'mind': 564,
#  'seen': 565,
#  'saturday': 566,
#  'alone': 567,
#  'launch': 568,
#  'welcome': 569,
#  'loved': 570,
#  'survivors': 571,
#  'timkaine': 572,
#  '–vp': 573,
#  'hillaryclinton': 574,
#  'hillary': 575,
#  'veterans': 576,
#  'battle': 577,
#  'equality': 578,
#  'until': 579,
#  'stay': 580,
#  'fall': 581,
#  "you're": 582,
#  'commit': 583,
#  'domestic': 584,
#  'quality': 585,
#  'privilege': 586,
#  'medicaid': 587,
#  'insurance': 588,
#  'number': 589,
#  'while': 590,
#  'record': 591,
#  'address': 592,
#  'free': 593,
#  'pledge': 594,
#  'companies': 595,
#  'union': 596,
#  'core': 597,
#  'democrats': 598,
#  'committed': 599,
#  'generations': 600,
#  'grassroots': 601,
#  'add': 602,
#  'attack': 603,
#  'carolina': 604,
#  'toward': 605,
#  'cannot': 606,
#  'deal': 607,
#  'freedom': 608,
#  'fundamentally': 609,
#  'drbiden': 610,
#  'abuse': 611,
#  'close': 612,
#  'happen': 613,
#  'lost': 614,
#  'women’s': 615,
#  'listen': 616,
#  'school': 617,
#  'trail': 618,
#  'little': 619,
#  'gave': 620,
#  'beau': 621,
#  'responsibility': 622,
#  'takes': 623,
#  'international': 624,
#  '21st': 625,
#  'faith': 626,
#  'you’ve': 627,
#  'gop': 628,
#  "they're": 629,
#  'son': 630,
#  "he's": 631,
#  'police': 632,
#  'called': 633,
#  '“it’s': 634,
#  '4': 635,
#  'fact': 636,
#  '“you': 637,
#  'buffettrule': 638,
#  'took': 639,
#  'civil': 640,
#  'government': 641,
#  'bold': 642,
#  'happening': 643,
#  'sense': 644,
#  'create': 645,
#  'stronger': 646,
#  'voter': 647,
#  'worked': 648,
#  'finish': 649,
#  'stood': 650,
#  'schools': 651,
#  'he’s': 652,
#  'stands': 653,
#  'political': 654,
#  'raise': 655,
#  'backbone': 656,
#  'disability': 657,
#  'decision': 658,
#  'candidates': 659,
#  'border': 660,
#  'entire': 661,
#  'yet': 662,
#  'face': 663,
#  'voice': 664,
#  'once': 665,
#  'secure': 666,
#  'justice': 667,
#  'movement': 668,
#  'celebrate': 669,
#  'idea': 670,
#  'kind': 671,
#  'elections': 672,
#  'detroit': 673,
#  'save': 674,
#  'others': 675,
#  'obligation': 676,
#  'behind': 677,
#  'become': 678,
#  'such': 679,
#  '6': 680,
#  'extend': 681,
#  'forget': 682,
#  'soon': 683,
#  'calls': 684,
#  'please': 685,
#  'five': 686,
#  'delaware': 687,
#  'dad': 688,
#  'sacrifice': 689,
#  'news': 690,
#  'anything': 691,
#  'understand': 692,
#  'saying': 693,
#  'excited': 694,
#  'congratulations': 695,
#  'millionaires': 696,
#  'hearts': 697,
#  'powerful': 698,
#  'changing': 699,
#  'entitled': 700,
#  'udelaware': 701,
#  'wrote': 702,
#  'bush': 703,
#  'count': 704,
#  'paul': 705,
#  'udbideninst': 706,
#  'pennbiden': 707,
#  'says': 708,
#  'hy8c4mil2m': 709,
#  'guy': 710,
#  'va': 711,
#  'wi': 712,
#  'ia': 713,
#  'nc': 714,
#  'case': 715,
#  '50': 716,
#  'brave': 717,
#  'following': 718,
#  'date': 719,
#  'including': 720,
#  'iraq': 721,
#  'pre': 722,
#  'wasn’t': 723,
#  'strength': 724,
#  'choose': 725,
#  'truth': 726,
#  'crisis': 727,
#  'title': 728,
#  'wealth': 729,
#  'wealthy': 730,
#  'away': 731,
#  'path': 732,
#  'three': 733,
#  'building': 734,
#  'voices': 735,
#  'republicans': 736,
#  'supporting': 737,
#  'beat': 738,
#  'simple': 739,
#  'brought': 740,
#  'organizing': 741,
#  'name': 742,
#  'safer': 743,
#  'south': 744,
#  'de': 745,
#  'los': 746,
#  'ed': 747,
#  'forum': 748,
#  'came': 749,
#  'anniversary': 750,
#  'won': 751,
#  'inspired': 752,
#  're': 753,
#  'cutting': 754,
#  'grateful': 755,
#  'sacred': 756,
#  'zip': 757,
#  'represent': 758,
#  'accept': 759,
#  'officers': 760,
#  'clinton': 761,
#  '11': 762,
#  'owe': 763,
#  'prayers': 764,
#  'tough': 765,
#  'city': 766,
#  'wait': 767,
#  'boston': 768,
#  'shared': 769,
#  'months': 770,
#  'nh': 771,
#  "you'll": 772,
#  'spirit': 773,
#  'officially': 774,
#  'whole': 775,
#  'scranton': 776,
#  'joined': 777,
#  'optimistic': 778,
#  'fl': 779,
#  'oh': 780,
#  'voted': 781,
#  'served': 782,
#  'whose': 783,
#  'stake': 784,
#  'pitch': 785,
#  'victims': 786,
#  'same': 787,
#  'deadline': 788,
#  'thoughts': 789,
#  'bidenfoundation': 790,
#  'basic': 791,
#  'importance': 792,
#  'then': 793,
#  'difference': 794,
#  'really': 795,
#  'patients': 796,
#  'example': 797,
#  'ending': 798,
#  'didn’t': 799,
#  'spoke': 800,
#  'washingtonpost': 801,
#  'phone': 802,
#  'pell': 803,
#  'grants': 804,
#  '“this': 805,
#  'morning': 806,
#  'kicks': 807,
#  "romney's": 808,
#  'romnesia': 809,
#  '”—vice': 810,
#  'madeinohio': 811,
#  'individuals': 812,
#  'changed': 813,
#  'laid': 814,
#  'research': 815,
#  'defeat': 816,
#  'mistake': 817,
#  'career': 818,
#  'dreamers': 819,
#  'immigrants': 820,
#  'pass': 821,
#  '✅': 822,
#  'expanded': 823,
#  'coverage': 824,
#  '20': 825,
#  'conditions': 826,
#  'd1o4wndczv': 827,
#  'wall': 828,
#  'fund': 829,
#  'ordinary': 830,
#  'extraordinary': 831,
#  'evidence': 832,
#  'agree': 833,
#  'tackle': 834,
#  'serve': 835,
#  'money': 836,
#  'chief': 837,
#  'reasons': 838,
#  'treatment': 839,
#  'couldn’t': 840,
#  'v': 841,
#  'reality': 842,
#  'para': 843,
#  'challenges': 844,
#  'op': 845,
#  'born': 846,
#  'recognize': 847,
#  'also': 848,
#  'they’re': 849,
#  'aid': 850,
#  'growing': 851,
#  '15': 852,
#  'denied': 853,
#  'kid': 854,
#  'determined': 855,
#  'cup': 856,
#  'fairness': 857,
#  'generation': 858,
#  '9': 859,
#  'thinks': 860,
#  'afford': 861,
#  'what’s': 862,
#  'someone': 863,
#  'mayor': 864,
#  'amazing': 865,
#  'ahead': 866,
#  'safety': 867,
#  'simply': 868,
#  'mi': 869,
#  'inspires': 870,
#  'available': 871,
#  'columbus': 872,
#  'march': 873,
#  'experience': 874,
#  'condolences': 875,
#  'start': 876,
#  'words': 877,
#  'started': 878,
#  'legacy': 879,
#  'votes': 880,
#  'pittsburgh': 881,
#  'labor': 882,
#  'fire': 883,
#  'among': 884,
#  'message': 885,
#  'credit': 886,
#  'late': 887,
#  'joe2020': 888,
#  'even': 889,
#  'friday': 890,
#  'led': 891,
#  'each': 892,
#  'colombia': 893,
#  'rape': 894,
#  'minutes': 895,
#  'december': 896,
#  'loss': 897,
#  "here's": 898,
#  'tuesday': 899,
#  'pa': 900,
#  'michigan': 901,
#  'data': 902,
#  'penn': 903,
#  'register': 904,
#  'remarkable': 905,
#  'guys': 906,
#  'keeping': 907,
#  'republican': 908,
#  'small': 909,
#  "you've": 910,
#  '🇺🇸': 911,
#  'second': 912,
#  'less': 913,
#  'gutsy': 914,
#  'businesses': 915,
#  'ad': 916,
#  '“my': 917,
#  'mn': 918,
#  'saw': 919,
#  'minnesota': 920,
#  'lady': 921,
#  'dnc2012': 922,
#  '2011': 923,
#  'apart': 924,
#  'forces': 925,
#  '1994': 926,
#  'major': 927,
#  'protections': 928,
#  'period': 929,
#  'immigration': 930,
#  'facing': 931,
#  'double': 932,
#  'mental': 933,
#  'street': 934,
#  'account': 935,
#  'evening': 936,
#  'field': 937,
#  'signing': 938,
#  'broken': 939,
#  'unite': 940,
#  'existential': 941,
#  'emergency': 942,
#  'funding': 943,
#  'poor': 944,
#  'defend': 945,
#  'reward': 946,
#  'rise': 947,
#  'regardless': 948,
#  'true': 949,
#  'hour': 950,
#  'question': 951,
#  'goes': 952,
#  'reason': 953,
#  'intolerance': 954,
#  'seeing': 955,
#  'eight': 956,
#  'attend': 957,
#  'epidemic': 958,
#  'que': 959,
#  'y': 960,
#  'las': 961,
#  'bringing': 962,
#  'held': 963,
#  'east': 964,
#  'especially': 965,
#  'unacceptable': 966,
#  '2019': 967,
#  'stopped': 968,
#  'strengthen': 969,
#  'instead': 970,
#  'nuclear': 971,
#  'both': 972,
#  'counts': 973,
#  'racism': 974,
#  'ideals': 975,
#  'failed': 976,
#  'rate': 977,
#  'stepping': 978,
#  'charlottesville': 979,
#  'process': 980,
#  '9pm': 981,
#  'parties': 982,
#  'rest': 983,
#  'fundamental': 984,
#  'child’s': 985,
#  'parents’': 986,
#  'mother': 987,
#  'trying': 988,
#  'luck': 989,
#  'gap': 990,
#  'paid': 991,
#  'father': 992,
#  'hundreds': 993,
#  'candidate': 994,
#  'integrity': 995,
#  'final': 996,
#  'senseless': 997,
#  'moral': 998,
#  'celebration': 999,
#  'tariffs': 1000,
#  ...}

# %%
word_index_dict = {
 'vp': 19,
 'president': 20,
 'country': 40,
 'america': 51,
 'every': 52,
 'obama': 57,
 'romney': 62,
 'middle': 63,
 'an': 64,
 'vote': 65,
 'can': 66,
 'work': 67,
 'joe': 68,
 'but': 69,
 'class': 70,
 '”—vp': 71,
 'women': 72,
 'do': 73,
 'back': 74,
 'campaign': 75,
 'now': 76,
 '—': 77,
 'so': 78,
 'no': 79,
 'he': 80,
 'years': 81,
 'last': 82,
 'american': 83,
 'or': 84,
 'take': 85,
 'if': 86,
 'time': 87,
 'need': 88,
 'plan': 89,
 'join': 90,
 'than': 91,
 'must': 92,
 'know': 93,
 'how': 94,
 'vice': 95,
 'me': 96,
 'them': 97,
 'never': 98,
 'great': 99,
 'new': 100,
 'just': 101,
 'there': 102,
 'jill': 103,
 'right': 104,
 'we’re': 105,
 'should': 106,
 'trump': 107,
 'like': 108,
 'watch': 109,
 'those': 110,
 'i’m': 111,
 'made': 112,
 'stand': 113,
 'first': 114,
 'here': 115,
 'families': 116,
 'violence': 117,
 'see': 118,
 'nation': 119,
 'would': 120,
 'health': 121,
 'care': 122,
 'dr': 123,
 'against': 124,
 'week': 125,
 'everyone': 126,
 'proud': 127,
 'way': 128,
 'when': 129,
 'forward': 130,
 'americans': 131,
 'tax': 132,
 'been': 133,
 'ryan': 134,
 'got': 135,
 'jobs': 136,
 'help': 137,
 'election': 138,
 'rights': 139,
 'debate': 140,
 'why': 141,
 'sure': 142,
 'act': 143,
 'thank': 144,
 'year': 145,
 'yesterday': 146,
 'world': 147,
 'because': 148,
 'over': 149,
 'going': 150,
 'hope': 151,
 'change': 152,
 'better': 153,
 'happy': 154,
 'go': 155,
 'these': 156,
 'support': 157,
 '“the': 158,
 'ohio': 159,
 'through': 160,
 'progress': 161,
 'live': 162,
 'fight': 163,
 'future': 164,
 'much': 165,
 'down': 166,
 'tomorrow': 167,
 'say': 168,
 'off': 169,
 '“we': 170,
 'security': 171,
 'good': 172,
 'where': 173,
 'together': 174,
 'teamjoe': 175,
 'only': 176,
 'medicare': 177,
 'community': 178,
 'lives': 179,
 'that’s': 180,
 'most': 181,
 'action': 182,
 'working': 183,
 'states': 187,
 'give': 188,
 'family': 191,
 'keep': 192,
 'climate': 193,
 'across': 194,
 'pay': 195,
 'education': 196,
 'love': 198,
 'her': 199,
 'dignity': 204,
 'voting': 205,
 'life': 211,
 'everything': 212,
 'administration': 213,
 'friend': 217,
 'folks': 219,
 'economy': 220,
 'without': 221,
 'making': 223,
 'senate': 224,
 'children': 225,
 'national': 227,
 'assault': 232,
 'talk': 237,
 'protect': 238,
 'single': 239,
 'united': 240,
 'million': 241,
 'students': 242,
 'believe': 243,
 'democracy': 244,
 'courage': 245,
 'rsvp': 246,
 'clear': 247,
 'state': 248,
 'teachers': 249,
 'fighting': 250,
 'policy': 251,
 'again': 254,
 'ensure': 256,
 'built': 257,
 'home': 258,
 'job': 259,
 'tune': 260,
 'incredible': 261,
 'workers': 262,
 'party': 263,
 'hard': 264,
 'speech': 265,
 'look': 266,
 'she': 267,
 'win': 268,
 'deserve': 269,
 'demdebate': 270,
 'important': 274,
 'safe': 276,
 'values': 277,
 'own': 278,
 'congress': 279,
 'policies': 281,
 'speak': 283,
 'remember': 284,
 'young': 285,
 'men': 286,
 'president’s': 289,
 'soul': 290,
 'energy': 291,
 'system': 293,
 'foreign': 299,
 'best': 300,
 'friends': 301,
 'story': 304,
 'obama2012': 305,
 'lgbtq': 306,
 'vision': 307,
 'thanks': 308,
 'follow': 309,
 'under': 310,
 'cut': 311,
 'communities': 312,
 'democratic': 324,
 'let’s': 329,
 'donald': 330,
 'gun': 331,
 'sexual': 334,
 'budget': 456,
 'millions': 461,
 '🇺🇸': 911,
 }

# %%
len(word_index_dict.keys())
# Out:
# 217

# %%
word_index_list = word_index_dict.keys()

# %%
wordcloud_list = []
for word in word_index_list:
    temp_dict = {'text': (word), 'value': (tokenizer_biden.word_counts[word])}
    wordcloud_list.append(temp_dict)

wordcloud_list
# Out:
# [{'text': 'vp', 'value': 313},
#  {'text': 'president', 'value': 273},
#  {'text': 'country', 'value': 125},
#  {'text': 'america', 'value': 99},
#  {'text': 'every', 'value': 99},
#  {'text': 'obama', 'value': 95},
#  {'text': 'romney', 'value': 88},
#  {'text': 'middle', 'value': 87},
#  {'text': 'an', 'value': 86},
#  {'text': 'vote', 'value': 85},
#  {'text': 'can', 'value': 84},
#  {'text': 'work', 'value': 84},
#  {'text': 'joe', 'value': 84},
#  {'text': 'but', 'value': 83},
#  {'text': 'class', 'value': 82},
#  {'text': '”—vp', 'value': 79},
#  {'text': 'women', 'value': 77},
#  {'text': 'do', 'value': 75},
#  {'text': 'back', 'value': 75},
#  {'text': 'campaign', 'value': 74},
#  {'text': 'now', 'value': 74},
#  {'text': '—', 'value': 73},
#  {'text': 'so', 'value': 73},
#  {'text': 'no', 'value': 72},
#  {'text': 'he', 'value': 69},
#  {'text': 'years', 'value': 67},
#  {'text': 'last', 'value': 67},
#  {'text': 'american', 'value': 67},
#  {'text': 'or', 'value': 67},
#  {'text': 'take', 'value': 66},
#  {'text': 'if', 'value': 66},
#  {'text': 'time', 'value': 66},
#  {'text': 'need', 'value': 63},
#  {'text': 'plan', 'value': 63},
#  {'text': 'join', 'value': 62},
#  {'text': 'than', 'value': 62},
#  {'text': 'must', 'value': 61},
#  {'text': 'know', 'value': 61},
#  {'text': 'how', 'value': 61},
#  {'text': 'vice', 'value': 59},
#  {'text': 'me', 'value': 59},
#  {'text': 'them', 'value': 58},
#  {'text': 'never', 'value': 58},
#  {'text': 'great', 'value': 57},
#  {'text': 'new', 'value': 57},
#  {'text': 'just', 'value': 56},
#  {'text': 'there', 'value': 54},
#  {'text': 'jill', 'value': 54},
#  {'text': 'right', 'value': 53},
#  {'text': 'we’re', 'value': 53},
#  {'text': 'should', 'value': 53},
#  {'text': 'trump', 'value': 52},
#  {'text': 'like', 'value': 52},
#  {'text': 'watch', 'value': 52},
#  {'text': 'those', 'value': 51},
#  {'text': 'i’m', 'value': 51},
#  {'text': 'made', 'value': 51},
#  {'text': 'stand', 'value': 50},
#  {'text': 'first', 'value': 50},
#  {'text': 'here', 'value': 49},
#  {'text': 'families', 'value': 48},
#  {'text': 'violence', 'value': 48},
#  {'text': 'see', 'value': 48},
#  {'text': 'nation', 'value': 47},
#  {'text': 'would', 'value': 47},
#  {'text': 'health', 'value': 47},
#  {'text': 'care', 'value': 47},
#  {'text': 'dr', 'value': 47},
#  {'text': 'against', 'value': 46},
#  {'text': 'week', 'value': 46},
#  {'text': 'everyone', 'value': 45},
#  {'text': 'proud', 'value': 45},
#  {'text': 'way', 'value': 45},
#  {'text': 'when', 'value': 45},
#  {'text': 'forward', 'value': 44},
#  {'text': 'americans', 'value': 44},
#  {'text': 'tax', 'value': 44},
#  {'text': 'been', 'value': 44},
#  {'text': 'ryan', 'value': 44},
#  {'text': 'got', 'value': 43},
#  {'text': 'jobs', 'value': 43},
#  {'text': 'help', 'value': 42},
#  {'text': 'election', 'value': 42},
#  {'text': 'rights', 'value': 41},
#  {'text': 'debate', 'value': 41},
#  {'text': 'why', 'value': 41},
#  {'text': 'sure', 'value': 41},
#  {'text': 'act', 'value': 41},
#  {'text': 'thank', 'value': 41},
#  {'text': 'year', 'value': 41},
#  {'text': 'yesterday', 'value': 40},
#  {'text': 'world', 'value': 39},
#  {'text': 'because', 'value': 39},
#  {'text': 'over', 'value': 39},
#  {'text': 'going', 'value': 38},
#  {'text': 'hope', 'value': 38},
#  {'text': 'change', 'value': 37},
#  {'text': 'better', 'value': 37},
#  {'text': 'happy', 'value': 37},
#  {'text': 'go', 'value': 37},
#  {'text': 'these', 'value': 36},
#  {'text': 'support', 'value': 36},
#  {'text': '“the', 'value': 36},
#  {'text': 'ohio', 'value': 36},
#  {'text': 'through', 'value': 35},
#  {'text': 'progress', 'value': 35},
#  {'text': 'live', 'value': 35},
#  {'text': 'fight', 'value': 34},
#  {'text': 'future', 'value': 34},
#  {'text': 'much', 'value': 34},
#  {'text': 'down', 'value': 34},
#  {'text': 'tomorrow', 'value': 34},
#  {'text': 'say', 'value': 34},
#  {'text': 'off', 'value': 33},
#  {'text': '“we', 'value': 33},
#  {'text': 'security', 'value': 33},
#  {'text': 'good', 'value': 33},
#  {'text': 'where', 'value': 32},
#  {'text': 'together', 'value': 32},
#  {'text': 'teamjoe', 'value': 32},
#  {'text': 'only', 'value': 32},
#  {'text': 'medicare', 'value': 32},
#  {'text': 'community', 'value': 32},
#  {'text': 'lives', 'value': 32},
#  {'text': 'that’s', 'value': 31},
#  {'text': 'most', 'value': 31},
#  {'text': 'action', 'value': 31},
#  {'text': 'working', 'value': 31},
#  {'text': 'states', 'value': 30},
#  {'text': 'give', 'value': 30},
#  {'text': 'family', 'value': 29},
#  {'text': 'keep', 'value': 29},
#  {'text': 'climate', 'value': 28},
#  {'text': 'across', 'value': 28},
#  {'text': 'pay', 'value': 28},
#  {'text': 'education', 'value': 28},
#  {'text': 'love', 'value': 28},
#  {'text': 'her', 'value': 28},
#  {'text': 'dignity', 'value': 27},
#  {'text': 'voting', 'value': 27},
#  {'text': 'life', 'value': 26},
#  {'text': 'everything', 'value': 25},
#  {'text': 'administration', 'value': 25},
#  {'text': 'friend', 'value': 25},
#  {'text': 'folks', 'value': 25},
#  {'text': 'economy', 'value': 24},
#  {'text': 'without', 'value': 24},
#  {'text': 'making', 'value': 24},
#  {'text': 'senate', 'value': 24},
#  {'text': 'children', 'value': 24},
#  {'text': 'national', 'value': 24},
#  {'text': 'assault', 'value': 23},
#  {'text': 'talk', 'value': 23},
#  {'text': 'protect', 'value': 22},
#  {'text': 'single', 'value': 22},
#  {'text': 'united', 'value': 22},
#  {'text': 'million', 'value': 22},
#  {'text': 'students', 'value': 22},
#  {'text': 'believe', 'value': 22},
#  {'text': 'democracy', 'value': 22},
#  {'text': 'courage', 'value': 22},
#  {'text': 'rsvp', 'value': 22},
#  {'text': 'clear', 'value': 22},
#  {'text': 'state', 'value': 22},
#  {'text': 'teachers', 'value': 22},
#  {'text': 'fighting', 'value': 22},
#  {'text': 'policy', 'value': 22},
#  {'text': 'again', 'value': 21},
#  {'text': 'ensure', 'value': 21},
#  {'text': 'built', 'value': 21},
#  {'text': 'home', 'value': 21},
#  {'text': 'job', 'value': 21},
#  {'text': 'tune', 'value': 21},
#  {'text': 'incredible', 'value': 21},
#  {'text': 'workers', 'value': 21},
#  {'text': 'party', 'value': 21},
#  {'text': 'hard', 'value': 21},
#  {'text': 'speech', 'value': 21},
#  {'text': 'look', 'value': 21},
#  {'text': 'she', 'value': 21},
#  {'text': 'win', 'value': 21},
#  {'text': 'deserve', 'value': 20},
#  {'text': 'demdebate', 'value': 20},
#  {'text': 'important', 'value': 20},
#  {'text': 'safe', 'value': 20},
#  {'text': 'values', 'value': 20},
#  {'text': 'own', 'value': 20},
#  {'text': 'congress', 'value': 20},
#  {'text': 'policies', 'value': 20},
#  {'text': 'speak', 'value': 20},
#  {'text': 'remember', 'value': 20},
#  {'text': 'young', 'value': 20},
#  {'text': 'men', 'value': 20},
#  {'text': 'president’s', 'value': 20},
#  {'text': 'soul', 'value': 19},
#  {'text': 'energy', 'value': 19},
#  {'text': 'system', 'value': 19},
#  {'text': 'foreign', 'value': 19},
#  {'text': 'best', 'value': 19},
#  {'text': 'friends', 'value': 19},
#  {'text': 'story', 'value': 19},
#  {'text': 'obama2012', 'value': 19},
#  {'text': 'lgbtq', 'value': 18},
#  {'text': 'vision', 'value': 18},
#  {'text': 'thanks', 'value': 18},
#  {'text': 'follow', 'value': 18},
#  {'text': 'under', 'value': 18},
#  {'text': 'cut', 'value': 18},
#  {'text': 'communities', 'value': 18},
#  {'text': 'democratic', 'value': 17},
#  {'text': 'let’s', 'value': 17},
#  {'text': 'donald', 'value': 17},
#  {'text': 'gun', 'value': 17},
#  {'text': 'sexual', 'value': 17},
#  {'text': 'budget', 'value': 13},
#  {'text': 'millions', 'value': 12},
#  {'text': '🇺🇸', 'value': 6}]

# %%
import json

with open('wordcloud_biden.json', 'w') as f:  # writing JSON object
    json.dump(wordcloud_list, f)

# %%
keys_dict = tokenizer.word_index.keys()
len(keys_dict)
# Out:
# 38669

# %%
# tokenizer.word_index['compassion']

# %%
tokenizer.word_counts['realdonaldtrump']
# Out:
# 1062

# %%
X_train_tokens = tokenizer.texts_to_sequences(X_train)

# %%
#NEED TO REPLACE WITH TEST DATA (TWEETS)
X_test_tokens = tokenizer.texts_to_sequences(X_test)
