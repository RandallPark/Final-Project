# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Downloads all tweets from a given user.
Uses twitter.Api.GetUserTimeline to retreive the last 3,200 tweets from a user.
Twitter doesn't allow retreiving more tweets than this through the API, so we get
as many as possible.
t.py should contain the imported variables.
"""

import json
import sys
import config

import twitter
from config import apikey, api_secret, access_token, access_token_s

# %%
def get_tweets(api=None, screen_name=p):
        print(f'NEW CALL FOR {p}')
        timeline = api.GetUserTimeline(screen_name=p, count=200)
        earliest_tweet = min(timeline, key=lambda x: x.id).id
        print("getting tweets before:", earliest_tweet)

        while True:
            tweets = api.GetUserTimeline(
                screen_name=p, max_id=earliest_tweet, count=200
            )
            new_earliest = min(tweets, key=lambda x: x.id).id
            
            print(f'Got past new_earliest ({new_earliest}) for politician {p}')

            if not tweets or new_earliest == earliest_tweet:
                print('BREAKING!!')
                break
            else:
                print('Got to ELSE, adding more tweets')
                earliest_tweet = new_earliest
                print("getting tweets before:", earliest_tweet)
                timeline += tweets

# SAVING TO INDIVIDUAL CSV
        csvname = p[1:]
                    
        with open(f'data_master/resources/{csvname}.csv', 'w+') as f:
            for tweet in timeline:
                f.write(json.dumps(tweet._json))
                f.write('\n')
                
        return timeline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e1a19a57f40a> in <module>
# ----> 1 def get_tweets(api=None, screen_name=p):
#       2         print(f'NEW CALL FOR {p}')
#       3         timeline = api.GetUserTimeline(screen_name=p, count=200)
#       4         earliest_tweet = min(timeline, key=lambda x: x.id).id
#       5         print("getting tweets before:", earliest_tweet)
#
# NameError: name 'p' is not defined

# %%
politic = ["@realDonaldTrump", "@marcorubio", "@mike_pence", "@BernieSanders",
           "@SenWarren", "@JoeBiden", "@tedcruz", "@Liz_Cheney", "@HouseGOP",
          "@HouseDemocrats", "@SenateDems", "@SenateGOP"]

api = twitter.Api(
                            apikey, api_secret, access_token, access_token_s, tweet_mode="extended"
                        )

for p in politic:
    get_tweets(api, p)
# Out:
# NEW CALL FOR @realDonaldTrump
# getting tweets before: 1139861610196066304
# Got past new_earliest (1135587640051490817) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1135587640051490817
# Got past new_earliest (1131158413373779968) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1131158413373779968
# Got past new_earliest (1127189799973076992) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1127189799973076992
# Got past new_earliest (1124645482553335808) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1124645482553335808
# Got past new_earliest (1120793199650463747) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1120793199650463747
# Got past new_earliest (1116360333436833792) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1116360333436833792
# Got past new_earliest (1109787378242240514) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1109787378242240514
# Got past new_earliest (1104506943887065089) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1104506943887065089
# Got past new_earliest (1098295228837048325) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1098295228837048325
# Got past new_earliest (1089691985164800001) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1089691985164800001
# Got past new_earliest (1084466503574016006) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1084466503574016006
# Got past new_earliest (1076575190899929088) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1076575190899929088
# Got past new_earliest (1069575605199482881) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1069575605199482881
# Got past new_earliest (1060923822851874816) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1060923822851874816
# Got past new_earliest (1056179047368134656) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1056179047368134656
# Got past new_earliest (1055127893112696832) for politician @realDonaldTrump
# Got to ELSE, adding more tweets
# getting tweets before: 1055127893112696832
# Got past new_earliest (1055127893112696832) for politician @realDonaldTrump
# BREAKING!!
# NEW CALL FOR @marcorubio
# getting tweets before: 1136246127517491202
# Got past new_earliest (1128712071401693184) for politician @marcorubio
# Got to ELSE, adding more tweets
# getting tweets before: 
for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1050848153526829056
# Got past new_earliest (1043628217385533442) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1043628217385533442
# Got past new_earliest (1037068067673657344) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1037068067673657344
# Got past new_earliest (1029815704705478658) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1029815704705478658
# Got past new_earliest (1020666249863458816) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1020666249863458816
# Got past new_earliest (1008844254419054592) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1008844254419054592
# Got past new_earliest (1007981359288053761) for politician @tedcruz
# Got to ELSE, adding more tweets
# getting tweets before: 1007981359288053761
# Got past new_earliest (1007981359288053761) for politician @tedcruz
# BREAKING!!
# NEW CALL FOR @Liz_Cheney
# getting tweets before: 1037833935856852992
# Got past new_earliest (946853153592320000) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 946853153592320000
# Got past new_earliest (812481803554590720) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 812481803554590720
# Got past new_earliest (764242887882055680) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 764242887882055680
# Got past new_earliest (718121825222455297) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 718121825222455297
# Got past new_earliest (606281154614849537) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 606281154614849537
# Got past new_earliest (548586374027165697) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 548586374027165697
# Got past new_earliest (370745502976839680) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 370745502976839680
# Got past new_earliest (216531906861346817) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 216531906861346817
# Got past new_earliest (169532417193943040) for politician @Liz_Cheney
# Got to ELSE, adding more tweets
# getting tweets before: 169532417193943040
# Got past new_earliest (169532417193943040) for politician @Liz_Cheney
# BREAKING!!
# NEW CALL FOR @HouseGOP
# getting tweets before: 1140712029914877957
# Got past new_earliest (1135980832294952962) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1135980832294952962
# Got past new_earliest (1130849426069581824) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1130849426069581824
# Got past new_earliest (1125797296304795648) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1125797296304795648
# Got past new_earliest (1119994215499431941) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1119994215499431941
# Got past new_earliest (1113131582221676545) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1113131582221676545
# Got past new_earliest (1103684840006868992) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1103684840006868992
# Got past new_earliest (1090021500600631298) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1090021500600631298
# Got past new_earliest (1059853063337492480) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1059853063337492480
# Got past new_earliest (1049659496258101248) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1049659496258101248
# Got past new_earliest (1042421302177349632) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1042421302177349632
# Got past new_earliest (1034923648061190146) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1034923648061190146
# Got past new_earliest (1024742814607798272) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1024742814607798272
# Got past new_earliest (1017433329929515008) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1017433329929515008
# Got past new_earliest (1008771328613027840) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 1008771328613027840
# Got past new_earliest (999655005383573505) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 999655005383573505
# Got past new_earliest (999001774534135808) for politician @HouseGOP
# Got to ELSE, adding more tweets
# getting tweets before: 999001774534135808
# Got past new_earliest (999001774534135808) for politician @HouseGOP
# BREAKING!!
# NEW CALL FOR @HouseDemocrats
# getting tweets before: 1124400486680018944
# Got past new_earliest (1100143801107124227) for politician @HouseDemocrats
# Got to ELSE, adding more tweets
# getting tweets before: 1100143801107124227
# Got past new_earliest (1088551329704886275) for politician @HouseDemocrats
# Got to ELSE, adding more tweets
# getting tweets before: 1088551329704886275
# Got past new_earliest (1073261528445530113) for politician @HouseDemocrats
# Got to ELSE, adding more tweets
# getting tweets before: