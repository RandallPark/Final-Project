# %%
import pandas as pd
from datetime import datetime
bs = pd.read_json("data_master/resources/berniesanders.json",lines=True)
created_time = []
for index, row in bs.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
bstweets = bs["full_text"]
t1_df= pd.DataFrame(bstweets)
t1_df = t1_df.rename(columns={'full_text': 'tweet'})
t1_df.insert(0, 'Political Affiliation', 'Democrats')
t1_df.insert(2, 'Politician', 'Bernie Sanders')
count = t1_df['tweet'].str.split().str.len()
t1_df['Word Count']=count
t1_df['created_time'] =created_time
t1_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  RT @CoriBush: The forward thinking &amp; coura...
# 1             Democrats  My skeptics often accuse me of being boring, o...
# 2             Democrats  Let's call this what it is: a racist and uncon...
# 3             Democrats  RT @amy4thepeople: @BernieSanders @CoriBush @p...
# 4             Democrats  When we are in the White House, we will have t...
#
#        Politician  Word Count created_time
# 0  Bernie Sanders          21      2019-06
# 1  Bernie Sanders          47      2019-06
# 2  Bernie Sanders          27      2019-06
# 3  Bernie Sanders          20      2019-06
# 4  Bernie Sanders          42      2019-06

# %%
t1woRT_df =t1_df[~t1_df.tweet.str.contains("RT")]
t1woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 1             Democrats  My skeptics often accuse me of being boring, o...
# 2             Democrats  Let's call this what it is: a racist and uncon...
# 4             Democrats  When we are in the White House, we will have t...
# 6             Democrats  Thank you @CoriBush, @paulajean2020, and @amy4...
# 9             Democrats  Today on #Stonewall50 we honor the brave peopl...
#
#        Politician  Word Count created_time
# 1  Bernie Sanders          47      2019-06
# 2  Bernie Sanders          27      2019-06
# 4  Bernie Sanders          42      2019-06
# 6  Bernie Sanders          29      2019-06
# 9  Bernie Sanders          36      2019-06

# %%
t1woRT_df.to_csv("data_master/resources/berniesanders_ft.csv", index=False)

# %%
hd = pd.read_json("data_master/resources/housedemocrats.json",lines=True)
created_time = []
for index, row in hd.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
hdtweets = hd["full_text"]
t2_df= pd.DataFrame(hdtweets)
t2_df = t2_df.rename(columns={'full_text': 'tweet'})
t2_df.insert(0, 'Political Affiliation', 'Democrats')
t2_df.insert(2, 'Politician', 'House of Democrats')
count = t2_df['tweet'].str.split().str.len()
t2_df['Word Count']=count
t2_df['created_time'] =created_time
t2woRT_df =t2_df[~t2_df.tweet.str.contains("RT")]
t2woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  NO American should worry about the cost of lif...
# 4             Democrats  ALL American families deserve to live in safe ...
# 6             Democrats  A targeted attack on our democracy is no laugh...
# 7             Democrats  House Democrats are FOCUSED on protecting our ...
# 8             Democrats  Mental health care is health care. We must pro...
#
#            Politician  Word Count created_time
# 0  House of Democrats          36      2019-06
# 4  House of Democrats          37      2019-06
# 6  House of Democrats          41      2019-06
# 7  House of Democrats          28      2019-06
# 8  House of Democrats          40      2019-06

# %%
t2woRT_df.to_csv("data_master/resources/housedemocrats_ft.csv", index=False)

# %%
hg = pd.read_json("data_master/resources/housegop.json",lines=True)
created_time = []
for index, row in hg.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
hgtweets = hg["full_text"]
t3_df= pd.DataFrame(hgtweets)
t3_df = t3_df.rename(columns={'full_text': 'tweet'})
t3_df.insert(0, 'Political Affiliation', 'Republican')
t3_df.insert(2, 'Politician', 'House of Republican')
count = t3_df['tweet'].str.split().str.len()
t3_df['Word Count']=count
t3_df['created_time'] =created_time
t3woRT_df =t3_df[~t3_df.tweet.str.contains("RT")]
t3woRT_df.head()
# Out:
#     Political Affiliation                                              tweet  \
# 10             Republican  "It is past time for Pelosi to allow the USMCA...
# 32             Republican  .@HouseDemocrats rejected efforts → 81 times ←...
# 67             Republican  Today @SpeakerPelosi is choosing to play polit...
# 74             Republican  Good luck to all of the @HouseGOP and @SenateG...
# 108            Republican  .@HomelandGOP's @RepMikeRogersAL on the border...
#
#               Politician  Word Count created_time
# 10   House of Republican          39      2019-06
# 32   House of Republican          28      2019-06
# 67   House of Republican          40      2019-06
# 74   House of Republican          27      2019-06
# 108  House of Republican          44      2019-06

# %%
t3woRT_df.to_csv("data_master/resources/housegop_ft.csv", index=False)

# %%
jb = pd.read_json("data_master/resources/joebiden.json",lines=True)
created_time = []
for index, row in jb.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
jbtweets = jb["full_text"]
t4_df= pd.DataFrame(jbtweets)
t4_df = t4_df.rename(columns={'full_text': 'tweet'})
t4_df.insert(0, 'Political Affiliation', 'Democrats')
t4_df.insert(2, 'Politician', 'Joe Biden')
count = t4_df['tweet'].str.split().str.len()
t4_df['Word Count']=count
t4_df['created_time'] =created_time
t4woRT_df =t4_df[~t4_df.tweet.str.contains("RT")]
t4woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  We're in a battle for the soul of this nation....
# 2             Democrats  Today marks 50 years since the Stonewall upris...
# 3             Democrats  I’ve fought my heart out to ensure that civil ...
# 5             Democrats  At last night’s first Democratic debate, I lai...
# 6             Democrats  I just got off the debate stage, where I laid ...
#
#   Politician  Word Count created_time
# 0  Joe Biden          46      2019-06
# 2  Joe Biden          45      2019-06
# 3  Joe Biden          50      2019-06
# 5  Joe Biden          43      2019-06
# 6  Joe Biden          51      2019-06

# %%
t4woRT_df.to_csv("data_master/resources/joebiden_ft.csv", index=False)

# %%
lc = pd.read_json("data_master/resources/Liz_Cheney.json",lines=True)
created_time = []
for index, row in lc.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
lctweets = lc["full_text"]
t5_df= pd.DataFrame(lctweets)
t5_df = t5_df.rename(columns={'full_text': 'tweet'})
t5_df.insert(0, 'Political Affiliation', 'Republican')
t5_df.insert(2, 'Politician', 'Liz Cheney')
count = t5_df['tweet'].str.split().str.len()
t5_df['Word Count']=count
t5_df['created_time'] =created_time
t5woRT_df =t5_df[~t5_df.tweet.str.contains("RT")]
t5woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0            Republican    Congratulations @USWNT! https://t.co/wFi3kQggjz
# 2            Republican  Main take away from #DemDebates: \n2020 Democr...
# 5            Republican      Listen and learn @AOC https://t.co/nq5CMyu8NT
# 6            Republican  Happy to help educate you @AOC. You could star...
# 7            Republican  Please @AOC do us all a favor and spend just a...
#
#    Politician  Word Count created_time
# 0  Liz Cheney           3      2019-06
# 2  Liz Cheney          34      2019-06
# 5  Liz Cheney           5      2019-06
# 6  Liz Cheney          35      2019-06
# 7  Liz Cheney          37      2019-06

# %%
t5woRT_df.to_csv("data_master/resources/lizcheney_ft.csv", index=False)

# %%
mr = pd.read_json("data_master/resources/marcorubio.json",lines=True)
created_time = []
for index, row in mr.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
mrtweets = mr["full_text"]
t6_df= pd.DataFrame(mrtweets)
t6_df = t6_df.rename(columns={'full_text': 'tweet'})
t6_df.insert(0, 'Political Affiliation', 'Republican')
t6_df.insert(2, 'Politician', 'Marco Rubio')
count = t6_df['tweet'].str.split().str.len()
t6_df['Word Count']=count
t6_df['created_time'] =created_time
t6woRT_df =t6_df[~t6_df.tweet.str.contains("RT")]
t6woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0            Republican  Q:Are you taking #Huawei off entity list?\n \n...
# 1            Republican  If President Trump has in fact bargained away ...
# 2            Republican  If President Trump has agreed to reverse recen...
# 3            Republican  US sanctions Maduro’s son as it raises pressur...
# 4            Republican  If America becomes a country that no longer ca...
#
#     Politician  Word Count created_time
# 0  Marco Rubio          41      2019-06
# 1  Marco Rubio          37      2019-06
# 2  Marco Rubio          41      2019-06
# 3  Marco Rubio          11      2019-06
# 4  Marco Rubio          36      2019-06

# %%
t6woRT_df.to_csv("data_master/resources/marcorubio_ft.csv", index=False)

# %%
mp = pd.read_json("data_master/resources/mike_pence.json",lines=True)
created_time = []
for index, row in mp.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
mptweets = mp["full_text"]
t7_df= pd.DataFrame(mptweets)
t7_df = t7_df.rename(columns={'full_text': 'tweet'})
t7_df.insert(0, 'Political Affiliation', 'Republican')
t7_df.insert(2, 'Politician', 'Mike Pence')
count = t7_df['tweet'].str.split().str.len()
t7_df['Word Count']=count
t7_df['created_time'] =created_time
t7woRT_df =t7_df[~t7_df.tweet.str.contains("RT")]
t7woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 1            Republican  The American dream is roaring back for all Ame...
# 2            Republican  Since Election Day 2016, businesses large and ...
# 3            Republican  The last 2.5 years under @realDonaldTrump have...
# 4            Republican  Democrats are in Miami tonight to make their c...
# 5            Republican  Latino Americans know that it was freedom, not...
#
#    Politician  Word Count created_time
# 1  Mike Pence          36      2019-06
# 2  Mike Pence          30      2019-06
# 3  Mike Pence          26      2019-06
# 4  Mike Pence          27      2019-06
# 5  Mike Pence          44      2019-06

# %%
t7woRT_df.to_csv("data_master/resources/mikepence_ft.csv", index=False)

# %%
dt = pd.read_json("data_master/resources/realDonaldTrump.json",lines=True)
created_time = []
for index, row in dt.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
dttweets = dt["full_text"]
t8_df= pd.DataFrame(dttweets)
t8_df = t8_df.rename(columns={'full_text': 'tweet'})
t8_df.insert(0, 'Political Affiliation', 'Republican')
t8_df.insert(2, 'Politician', 'Donald Trump')
count = t8_df['tweet'].str.split().str.len()
t8_df['Word Count']=count
t8_df['created_time'] =created_time
t8woRT_df =t8_df[~t8_df.tweet.str.contains("RT")]
t8woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0            Republican  Thank you #G20OsakaSummit https://t.co/9FCqSuR5Bp
# 1            Republican  After some very important meetings, including ...
# 2            Republican  54% in Poll! I would be at 75% (with our great...
# 3            Republican  I am in Japan at the G-20, representing our Co...
# 4            Republican  The Stock Market went up massively from the da...
#
#      Politician  Word Count created_time
# 0  Donald Trump           4      2019-06
# 1  Donald Trump          49      2019-06
# 2  Donald Trump          28      2019-06
# 3  Donald Trump          39      2019-06
# 4  Donald Trump          56      2019-06

# %%
t8woRT_df.to_csv("data_master/resources/donaldtrump_ft.csv", index=False)

# %%
sd = pd.read_json("data_master/resources/SenateDems.json",lines=True)
created_time = []
for index, row in sd.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
sdtweets = sd["full_text"]
t9_df= pd.DataFrame(sdtweets)
t9_df = t9_df.rename(columns={'full_text': 'tweet'})
t9_df.insert(0, 'Political Affiliation', 'Democrats')
t9_df.insert(2, 'Politician', 'Senate of Democrats')
count = t9_df['tweet'].str.split().str.len()
t9_df['Word Count']=count
t9_df['created_time'] =created_time
t9woRT_df =t9_df[~t9_df.tweet.str.contains("RT")]
t9woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 5             Democrats  “We should insist that we have the authority a...
# 6             Democrats  “To date, the administration seems to have tri...
# 7             Democrats  WATCH: @SenJeffMerkley calls on senators to ho...
# 8             Democrats  “Tomorrow, we will all speak to a fundamental ...
# 9             Democrats  “The Udall amendment would mark the beginning ...
#
#             Politician  Word Count created_time
# 5  Senate of Democrats          31      2019-06
# 6  Senate of Democrats          36      2019-06
# 7  Senate of Democrats          22      2019-06
# 8  Senate of Democrats          41      2019-06
# 9  Senate of Democrats          30      2019-06

# %%
t9woRT_df.to_csv("data_master/resources/senatedemocrats_ft.csv", index=False)

# %%
sg = pd.read_json("data_master/resources/senategop.json",lines=True)
created_time = []
for index, row in sg.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
sgtweets = sg["full_text"]
t10_df= pd.DataFrame(sgtweets)
t10_df = t10_df.rename(columns={'full_text': 'tweet'})
t10_df.insert(0, 'Political Affiliation', 'Republican')
t10_df.insert(2, 'Politician', 'Senate of Republican')
count = t10_df['tweet'].str.split().str.len()
t10_df['Word Count']=count
t10_df['created_time']=created_time
t10woRT_df =t10_df[~t10_df.tweet.str.contains("RT")]
t10woRT_df.head()
# Out:
#    Political Affiliation                                              tweet  \
# 1             Republican  GREAT NEWS! This week, the Senate passed the b...
# 20            Republican  58 days.\n \n81 efforts blocked in the House.\...
# 27            Republican  ✅ PASSED: The National Defense Authorization A...
# 33            Republican  .@HouseDemocrats: This crisis demands action. ...
# 41            Republican  By an overwhelming 84-8 vote, the Senate just ...
#
#               Politician  Word Count created_time
# 1   Senate of Republican          31      2019-06
# 20  Senate of Republican          25      2019-06
# 27  Senate of Republican          29      2019-06
# 33  Senate of Republican          10      2019-06
# 41  Senate of Republican          37      2019-06

# %%
t10woRT_df.to_csv("data_master/resources/senaterepublican_ft.csv", index=False)

# %%
sw = pd.read_json("data_master/resources/senwarren.json",lines=True)
created_time = []
for index, row in sw.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
swtweets = sw["full_text"]
t11_df= pd.DataFrame(swtweets)
t11_df = t11_df.rename(columns={'full_text': 'tweet'})
t11_df.insert(0, 'Political Affiliation', 'Democrats')
t11_df.insert(2, 'Politician', 'Senator Warren')
count = t11_df['tweet'].str.split().str.len()
t11_df['Word Count']=count
t11_df['created_time']=created_time
t11woRT_df =t11_df[~t11_df.tweet.str.contains("RT")]
t11woRT_df.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  @CFPB @splcenter @RepKatiePorter @RepPressley ...
# 1             Democrats  The @CFPB’s Director of the Office of Innovati...
# 2             Democrats  Whether @realDonaldTrump likes it or not, he n...
# 3             Democrats  .@realDonaldTrump and his band of war hawks @S...
# 4             Democrats  I wrote to @BalfourBeatty &amp; the @USAirForc...
#
#        Politician  Word Count created_time
# 0  Senator Warren          40      2019-06
# 1  Senator Warren          37      2019-06
# 2  Senator Warren          42      2019-06
# 3  Senator Warren          36      2019-06
# 4  Senator Warren          33      2019-06

# %%
t11woRT_df.to_csv("data_master/resources/senwarren_ft.csv", index=False)

# %%
sw = pd.read_json("data_master/resources/tedcruz.json",lines=True)
created_time = []
for index, row in sw.iterrows():
#     ts = time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(row['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
    ts = datetime.strftime(row.created_at,'%Y-%m')
    created_time.append(ts)
swtweets = sw["full_text"]
t12_df= pd.DataFrame(swtweets)
t12_df = t12_df.rename(columns={'full_text': 'tweet'})
t12_df.insert(0, 'Political Affiliation', 'Republican')
t12_df.insert(2, 'Politician', 'Ted Cruz')
count = t11_df['tweet'].str.split().str.len()
t12_df['Word Count']=count
t12_df['created_time']=created_time
t12woRT_df =t12_df[~t12_df.tweet.str.contains("RT")]
t12woRT_df.head()
# Out:
#    Political Affiliation                                              tweet  \
# 0             Republican  Help #KeepTexasRed and build our majority in t...
# 11            Republican  We are going to defend freedom in the United S...
# 13            Republican  This is the ideological diversity of 2020 Dems...
# 14            Republican  Occasionally, facts matter. But not on 2020 De...
# 16            Republican                      True. https://t.co/7VqAB9SoX3
#
#    Politician  Word Count created_time
# 0    Ted Cruz        40.0      2019-06
# 11   Ted Cruz        23.0      2019-06
# 13   Ted Cruz        40.0      2019-06
# 14   Ted Cruz        38.0      2019-06
# 16   Ted Cruz        43.0      2019-06

# %%
t12woRT_df.to_csv("data_master/resources/tedcruz_ft.csv", index=False)

# %%
#Democrats
merge12 = pd.merge(t1woRT_df,t2woRT_df, how = "outer")
merge49 = pd.merge(t4woRT_df,t9woRT_df,how = "outer")
merge1249 = pd.merge(merge49,merge12,how = "outer")
merge_democrats =pd.merge(merge1249,t11woRT_df,how = "outer")
merge_democrats.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0             Democrats  We're in a battle for the soul of this nation....
# 1             Democrats  Today marks 50 years since the Stonewall upris...
# 2             Democrats  I’ve fought my heart out to ensure that civil ...
# 3             Democrats  At last night’s first Democratic debate, I lai...
# 4             Democrats  I just got off the debate stage, where I laid ...
#
#   Politician  Word Count created_time
# 0  Joe Biden          46      2019-06
# 1  Joe Biden          45      2019-06
# 2  Joe Biden          50      2019-06
# 3  Joe Biden          43      2019-06
# 4  Joe Biden          51      2019-06

# %%
merge_democrats.count()
# Out:
# Political Affiliation    9054
# tweet                    9054
# Politician               9054
# Word Count               9054
# created_time             9054
# dtype: int64

# %%
merge_democrats.to_csv("data_master/resources/democrats_ft.csv",index=False)

# %%
#Republican

merge35 = pd.merge(t3woRT_df,t5woRT_df, how = "outer")
merge67 = pd.merge(t6woRT_df,t7woRT_df,how = "outer")
merge810 = pd.merge(t8woRT_df,t10woRT_df,how = "outer")
merge3567 =pd.merge(merge35,merge67,how = "outer")
merge81012 =pd.merge(merge810,t12woRT_df,how = "outer")
merge_republican =pd.merge(merge3567,merge81012,how = "outer")
merge_republican.head()
# Out:
#   Political Affiliation                                              tweet  \
# 0            Republican  "It is past time for Pelosi to allow the USMCA...
# 1            Republican  .@HouseDemocrats rejected efforts → 81 times ←...
# 2            Republican  Today @SpeakerPelosi is choosing to play polit...
# 3            Republican  Good luck to all of the @HouseGOP and @SenateG...
# 4            Republican  .@HomelandGOP's @RepMikeRogersAL on the border...
#
#             Politician  Word Count created_time
# 0  House of Republican        39.0      2019-06
# 1  House of Republican        28.0      2019-06
# 2  House of Republican        40.0      2019-06
# 3  House of Republican        27.0      2019-06
# 4  House of Republican        44.0      2019-06

# %%
merge_republican.count()
# Out:
# Political Affiliation    12749
# tweet                    12749
# Politician               12749
# Word Count               12746
# created_time             12749
# dtype: int64

# %%
merge_republican.to_csv("data_master/resources/republican_ft.csv",index=False)
