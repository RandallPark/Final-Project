# %%
import pandas as pd

# %%
senategop = pd.read_json("examples/SenateGOP.json",lines=True)

# %%
senategop.head()
# Out:
#    contributors  coordinates          created_at  \
# 0           NaN          NaN 2019-06-26 00:15:28
# 1           NaN          NaN 2019-06-25 23:54:56
# 2           NaN          NaN 2019-06-25 22:06:05
# 3           NaN          NaN 2019-06-25 20:52:20
# 4           NaN          NaN 2019-06-25 19:31:01
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [{'text': 'NDAA', 'indices': [50,...               NaN
#
#    favorite_count  favorited  geo                   id               id_str  \
# 0               0      False  NaN  1143674099396468736  1143674099396468736
# 1               0      False  NaN  1143668933272231943  1143668933272231936
# ...

# %%
tweets = senategop["text"]
tweets.head()
# Out:
# 0    RT @SASCMajority: The United States is the gre...
# 1    RT @JimInhofe: It’s been eight weeks since @re...
# 2    RT @SenThomTillis: I spoke on the Senate floor...
# 3    Iran’s recent aggression is a reminder of the ...
# 4    RT @SenCapito: Ready to vote “yes” on this yea...
# Name: text, dtype: object

# %%
t_df= pd.DataFrame(tweets)
t_df.head()
# Out:
#                                                 text
# 0  RT @SASCMajority: The United States is the gre...
# 1  RT @JimInhofe: It’s been eight weeks since @re...
# 2  RT @SenThomTillis: I spoke on the Senate floor...
# 3  Iran’s recent aggression is a reminder of the ...
# 4  RT @SenCapito: Ready to vote “yes” on this yea...

# %%
t_df.colums = ["tweet text"]
# Out:
# C:\Users\purchasing\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
t_df = t_df.rename(columns={'text': 'tweet'})
t_df.head()
# Out:
#                                                tweet
# 0  RT @SASCMajority: The United States is the gre...
# 1  RT @JimInhofe: It’s been eight weeks since @re...
# 2  RT @SenThomTillis: I spoke on the Senate floor...
# 3  Iran’s recent aggression is a reminder of the ...
# 4  RT @SenCapito: Ready to vote “yes” on this yea...

# %%
t_df.insert(0, 'Political Affiliation', 'Republican')

# %%
t_df.head()
# Out:
#   Political Affiliation                                              tweet
# 0            Republican  RT @SASCMajority: The United States is the gre...
# 1            Republican  RT @JimInhofe: It’s been eight weeks since @re...
# 2            Republican  RT @SenThomTillis: I spoke on the Senate floor...
# 3            Republican  Iran’s recent aggression is a reminder of the ...
# 4            Republican  RT @SenCapito: Ready to vote “yes” on this yea...
